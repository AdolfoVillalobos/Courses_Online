# %% [markdown]
# # Multi-Layer Perceptron, MNIST
# ---
# In this notebook, we will train an MLP to classify images from the [MNIST database](http://yann.lecun.com/exdb/mnist/) hand-written digit database.
#
# The process will be broken down into the following steps:
# >1. Load and visualize the data
# 2. Define a neural network
# 3. Train the model
# 4. Evaluate the performance of our trained model on a test dataset!
#
# Before we begin, we have to import the necessary libraries for working with data and PyTorch.

# %%
# import libraries
import torch
import numpy as np
from torchsummary import summary

# %% [markdown]
# ---
# ## Load and Visualize the [Data](http://pytorch.org/docs/stable/torchvision/datasets.html)
#
# Downloading may take a few moments, and you should see your progress as the data is loading. You may also choose to change the `batch_size` if you want to load more data at a time.
#
# This cell will create DataLoaders for each of our datasets.

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training to use as validation
valid_size = 0.2

# convert data to torch.FloatTensor
transform = transforms.ToTensor()

# choose the training and test datasets
train_data = datasets.MNIST(root='data', train=True,
                                   download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False,
                                  download=True, transform=transform)

# Obtaining training and validation indices
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size*num_train))
print(split)
train_idx, val_idx = indices[split:], indices[:split]

# Define samplers for training and validation batches

train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(val_idx)


# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    num_workers=num_workers, sampler=train_sampler)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    num_workers=num_workers, sampler=valid_sampler)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)
# Out:
# 12000

# %%
print(len(train_loader))
print(len(valid_loader))
print(len(test_loader))
# Out:
# 2400
# 600
# 500

# %% [markdown]
# ### Visualize a Batch of Training Data
#
# The first step in a classification task is to take a look at the data, make sure it is loaded in correctly, then make any initial observations about patterns in that data.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
    
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    # print out the correct label for each image
    # .item() gets the value contained in a Tensor
    ax.set_title(str(labels[idx].item()))

# %% [markdown]
# ### View an Image in More Detail

# %%
img = np.squeeze(images[1])

fig = plt.figure(figsize = (12,12)) 
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y],2) if img[x][y] !=0 else 0
        ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center',
                    color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ---
# ## Define the Network [Architecture](http://pytorch.org/docs/stable/nn.html)
#
# The architecture will be responsible for seeing as input a 784-dim Tensor of pixel values for each image, and producing a Tensor of length 10 (our number of classes) that indicates the class scores for an input image. This particular example uses two hidden layers and dropout to avoid overfitting.

# %%
import torch.nn as nn
import torch.nn.functional as F

## TODO: Define the NN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        hidden_1 = 512
        hidden_2 = 256
        self.fc1 = nn.Linear(28 * 28, hidden_1)
        self.fc2 = nn.Linear(hidden_1, hidden_2)
        self.fc3 = nn.Linear(hidden_2, 10)
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        return x

# initialize the NN
model = Net()
device = 'cuda:0'
model.to(device)
summary(model, input_size=(3,28,28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 512]         401,920
#            Dropout-2                  [-1, 512]               0
#             Linear-3                  [-1, 256]         131,328
#            Dropout-4                  [-1, 256]               0
#             Linear-5                   [-1, 10]           2,570
# ================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.01
# Params size (MB): 2.04
# Estimated Total Size (MB): 2.06
# ----------------------------------------------------------------

# %% [markdown]
# ###  Specify [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)
#
# It's recommended that you use cross-entropy loss for classification. If you look at the documentation (linked above), you can see that PyTorch's cross entropy function applies a softmax funtion to the output layer *and* then calculates the log loss.

# %%
## TODO: Specify loss and optimization functions

# specify loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.01)

# %% [markdown]
# ---
# ## Train the Network
#
# The steps for training/learning from a batch of data are described in the comments below:
# 1. Clear the gradients of all optimized variables
# 2. Forward pass: compute predicted outputs by passing inputs to the model
# 3. Calculate the loss
# 4. Backward pass: compute gradient of the loss with respect to model parameters
# 5. Perform a single optimization step (parameter update)
# 6. Update average training loss
#
# The following loop trains for 30 epochs; feel free to change this number. For now, we suggest somewhere between 20-50 epochs. As you train, take a look at how the values for the training loss decrease over time. We want it to decrease while also avoiding overfitting the training data.

# %%
# number of epochs to train the model
n_epochs =  50  # suggest training between 20-50 epochs
valid_loss_min = np.Inf 


model.train() # prep model for training

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data.to(device))
        # calculate the loss
        loss = criterion(output, target.to(device))
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)

    for data, target in valid_loader:
      output = model(data.to(device))
      loss = criterion(output, target.to(device))
      valid_loss += loss.item()*data.size(0)

        
    # print training statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(valid_loader.sampler)

    print('Epoch: {} \tTraining Loss: {:.6f} \tValidLoss Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # Save model if validation loss has decreased

    if valid_loss <= valid_loss_min:
      print("Validation loss decreased ({:6f} --> {:6f}). Saving model ...".format(
          valid_loss_min, valid_loss
      ))
      torch.save(model.state_dict(), 'model.pt')
      valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.183321 	ValidLoss Loss: 0.192338
# Validation loss decreased (   inf --> 0.192338). Saving model ...
# Epoch: 2 	Training Loss: 0.161910 	ValidLoss Loss: 0.174174
# Validation loss decreased (0.192338 --> 0.174174). Saving model ...
# Epoch: 3 	Training Loss: 0.141697 	ValidLoss Loss: 0.161324
# Validation loss decreased (0.174174 --> 0.161324). Saving model ...
# Epoch: 4 	Training Loss: 0.129397 	ValidLoss Loss: 0.152461
# Validation loss decreased (0.161324 --> 0.152461). Saving model ...
# Epoch: 5 	Training Loss: 0.118018 	ValidLoss Loss: 0.141725
# Validation loss decreased (0.152461 --> 0.141725). Saving model ...
# Epoch: 6 	Training Loss: 0.106855 	ValidLoss Loss: 0.131174
# Validation loss decreased (0.141725 --> 0.131174). Saving model ...
# Epoch: 7 	Training Loss: 0.098504 	ValidLoss Loss: 0.126747
# Validation loss decreased (0.131174 --> 0.126747). Saving model ...
# Epoch: 8 	Training Loss: 0.089662 	ValidLoss Loss: 0.123842
# Validation loss decreased (0.126747 --> 0.123842). Saving model ...
# Epoch: 9 	Training Loss: 0.086016 	ValidLoss Loss: 0.116174
# Validation loss decreased (0.123842 --> 0.116174). Saving model ...
# Epoch: 10 	Training Loss: 0.079438 	ValidLoss Loss: 0.113467
# Validation loss decreased (0.116174 --> 0.113467). Saving model ...
# Epoch: 11 	Training Loss: 0.074123 	ValidLoss Loss: 0.108986
# Validation loss decreased (0.113467 --> 0.108986). Saving model ...
# Epoch: 12 	Training Loss: 0.069097 	ValidLoss Loss: 0.107931
# Validation loss decreased (0.108986 --> 0.107931). Saving model ...
# Epoch: 13 	Training Loss: 0.064646 	ValidLoss Loss: 0.105900
# Validation loss decreased (0.107931 --> 0.105900). Saving model ...
# Epoch: 14 	Training Loss: 0.061891 	ValidLoss Loss: 0.102447
# Validation loss decreased (0.105900 --> 0.102447). Saving model ...
# Epoch: 15 	Training Loss: 0.057948 	ValidLoss Loss: 0.102101
# Validation loss decreased (0.102447 --> 0.102101). Saving model ...
# Epoch: 16 	Training Loss: 0.053994 	ValidLoss Loss: 0.098341
# Validation loss decreased (0.102101 --> 0.098341). Saving model ...
# Epoch: 17 	Training Loss: 0.050252 	ValidLoss Loss: 0.095539
# Validation loss decreased (0.098341 --> 0.095539). Saving model ...
# Epoch: 18 	Training Loss: 0.047781 	ValidLoss Loss: 0.092392
# Validation loss decreased (0.095539 --> 0.092392). Saving model ...
# Epoch: 19 	Training Loss: 0.045701 	ValidLoss Loss: 0.092564
# Epoch: 20 	Training Loss: 0.043949 	ValidLoss Loss: 0.094952
# Epoch: 21 	Training Loss: 0.041641 	ValidLoss Loss: 0.090551
# Validation loss decreased (0.092392 --> 0.090551). Saving model ...
# Epoch: 22 	Training Loss: 0.038781 	ValidLoss Loss: 0.092152
# Epoch: 23 	Training Loss: 0.036297 	ValidLoss Loss: 0.090619
# Epoch: 24 	Training Loss: 0.034054 	ValidLoss Loss: 0.087223
# Validation loss decreased (0.090551 --> 0.087223). Saving model ...
# Epoch: 25 	Training Loss: 0.032852 	ValidLoss Loss: 0.089719
# Epoch: 26 	Training Loss: 0.030824 	ValidLoss Loss: 0.088457
# Epoch: 27 	Training Loss: 0.030875 	ValidLoss Loss: 0.090850
# Epoch: 28 	Training Loss: 0.028170 	ValidLoss Loss: 0.086029
# Validation loss decreased (0.087223 --> 0.086029). Saving model ...
# Epoch: 29 	Training Loss: 0.028231 	ValidLoss Loss: 0.088165
# Epoch: 30 	Training Loss: 0.027420 	ValidLoss Loss: 0.087167
# Epoch: 31 	Training Loss: 0.025345 	ValidLoss Loss: 0.084297
# Validation loss decreased (0.086029 --> 0.084297). Saving model ...
# Epoch: 32 	Training Loss: 0.024012 	ValidLoss Loss: 0.089581
# Epoch: 33 	Training Loss: 0.022486 	ValidLoss Loss: 0.090686
# Epoch: 34 	Training Loss: 0.021649 	ValidLoss Loss: 0.089836
# Epoch: 35 	Training Loss: 0.021517 	ValidLoss Loss: 0.087842
# Epoch: 36 	Training Loss: 0.020130 	ValidLoss Loss: 0.084239
# Validation loss decreased (0.084297 --> 0.084239). Saving model ...
# Epoch: 37 	Training Loss: 0.020565 	ValidLoss Loss: 0.091095
# Epoch: 38 	Training Loss: 0.018145 	ValidLoss Loss: 0.085337
# Epoch: 39 	Training Loss: 0.018195 	ValidLoss Loss: 0.083919
# Validation loss decreased (0.084239 --> 0.083919). Saving model ...
# Epoch: 40 	Training Loss: 0.017255 	ValidLoss Loss: 0.086573
# Epoch: 41 	Training Loss: 0.017539 	ValidLoss Loss: 0.082516
# Validation loss decreased (0.083919 --> 0.082516). Saving model ...
# Epoch: 42 	Training Loss: 0.016591 	ValidLoss Loss: 0.086922
# Epoch: 43 	Training Loss: 0.015329 	ValidLoss Loss: 0.085371
# Epoch: 44 	Training Loss: 0.015088 	ValidLoss Loss: 0.086371
# Epoch: 45 	Training Loss: 0.014136 	ValidLoss Loss: 0.084113
# Epoch: 46 	Training Loss: 0.013848 	ValidLoss Loss: 0.082726
# Epoch: 47 	Training Loss: 0.013942 	ValidLoss Loss: 0.086845
# Epoch: 48 	Training Loss: 0.012695 	ValidLoss Loss: 0.086660
# Epoch: 49 	Training Loss: 0.012285 	ValidLoss Loss: 0.084605
# Epoch: 50 	Training Loss: 0.012335 	ValidLoss Loss: 0.086764

# %% [markdown]
# ---
# ## Test the Trained Network
#
# Finally, we test our best model on previously unseen **test data** and evaluate it's performance. Testing on unseen data is a good way to check that our model generalizes well. It may also be useful to be granular in this analysis and take a look at how this model performs on each class as well as looking at its overall loss and accuracy.
#
# #### `model.eval()`
#
# `model.eval(`) will set all the layers in your model to evaluation mode. This affects layers like dropout layers that turn "off" nodes during training with some probability, but should allow every node to be "on" for evaluation!

# %%
model.load_state_dict(torch.load('model.pt'))
# Out:
# <All keys matched successfully>

# %%
# initialize lists to monitor test loss and accuracy
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval() # prep model for *evaluation*

for data, target in test_loader:
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data.to(device))
    # calculate the loss
    loss = criterion(output, target.to(device))
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.to(device).data.view_as(pred.to(device))))
    # calculate test accuracy for each object class
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate and print avg test loss
test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.057168
#
# Test Accuracy of     0: 99% (972/980)
# Test Accuracy of     1: 99% (1124/1135)
# Test Accuracy of     2: 98% (1013/1032)
# Test Accuracy of     3: 98% (995/1010)
# Test Accuracy of     4: 98% (963/982)
# Test Accuracy of     5: 98% (876/892)
# Test Accuracy of     6: 98% (941/958)
# Test Accuracy of     7: 98% (1008/1028)
# Test Accuracy of     8: 97% (949/974)
# Test Accuracy of     9: 98% (989/1009)
#
# Test Accuracy (Overall): 98% (9830/10000)

# %% [markdown]
# ### Visualize Sample Test Results
#
# This cell displays test images and their labels in this format: `predicted (ground-truth)`. The text will be green for accurately classified examples and red for incorrect predictions.

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()

# get sample outputs
output = model(images.to(device))
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title("{} ({})".format(str(preds[idx].item()), str(labels[idx].item())),
                 color=("green" if preds[idx]==labels[idx] else "red"))
